# %% [markdown]
# # Using the new set of samples to build the mathematical model from scratch, as well as move on to actuation feasbility maps

# %% [markdown]
# # Tailoring actuation feasibilty maps according to literature applications
